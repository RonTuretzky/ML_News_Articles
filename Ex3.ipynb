# %%
# !pip uninstall torch
# Out:
# Found existing installation: torch 1.11.0+cu113
# Uninstalling torch-1.11.0+cu113:
#   Would remove:
#     /usr/local/bin/convert-caffe2-to-onnx
#     /usr/local/bin/convert-onnx-to-caffe2
#     /usr/local/bin/torchrun
#     /usr/local/lib/python3.7/dist-packages/caffe2/*
#     /usr/local/lib/python3.7/dist-packages/torch-1.11.0+cu113.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/torch/*
# Proceed (y/n)? y
#   Successfully uninstalled torch-1.11.0+cu113

# %%
# !pip install --pre torch -f https://download.pytorch.org/whl/nightly/cpu/torch_nightly.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/nightly/cpu/torch_nightly.html
# Collecting torch
#   Downloading https://download.pytorch.org/whl/nightly/cpu/torch-1.13.0.dev20220525%2Bcpu-cp37-cp37m-linux_x86_64.whl (189.3 MB)
#      |████████████████████████████████| 189.3 MB 45 kB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.2.0)
# Installing collected packages: torch
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.12.0+cu113 requires torch==1.11.0, but you have torch 1.13.0.dev20220525+cpu which is incompatible.
# torchtext 0.12.0 requires torch==1.11.0, but you have torch 1.13.0.dev20220525+cpu which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.13.0.dev20220525+cpu which is incompatible.
# Successfully installed torch-1.13.0.dev20220525+cpu

# %%
# !pip install --user "git+https://github.com/pytorch/data.git"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/pytorch/data.git
#   Cloning https://github.com/pytorch/data.git to /tmp/pip-req-build-shnq0359
#   Running command git clone -q https://github.com/pytorch/data.git /tmp/pip-req-build-shnq0359
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchdata==0.5.0a0+24ff1b5) (2.23.0)
# Collecting portalocker>=2.0.0
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Collecting urllib3>=1.25
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 4.5 MB/s
# Requirement already satisfied: torch>1.11.0 in /usr/local/lib/python3.7/dist-packages (from torchdata==0.5.0a0+24ff1b5) (1.13.0.dev20220525+cpu)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>1.11.0->torchdata==0.5.0a0+24ff1b5) (4.2.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchdata==0.5.0a0+24ff1b5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchdata==0.5.0a0+24ff1b5) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchdata==0.5.0a0+24ff1b5) (2022.5.18.1)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 44.9 MB/s
# Building wheels for collected packages: torchdata
#   Building wheel for torchdata (PEP 517) ... done
#   Created wheel for torchdata: filename=torchdata-0.5.0a0+24ff1b5-py3-none-any.whl size=87138 sha256=8d6b44c80ce73f427f06add3414d05b2bf43a8424a91a08e472ea1a3a98b56c4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0koene6l/wheels/a9/4f/7a/6edd9e915eb0cf0d88565db0f14b9b2b83e5f9f56c192042ad
# Successfully built torchdata
# Installing collected packages: urllib3, portalocker, torchdata
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed portalocker-2.4.0 torchdata-0.5.0a0+24ff1b5 urllib3-1.25.11

# %%
import torch
from torchtext.datasets import AG_NEWS
train_iter = iter(AG_NEWS(split='train'))
# Out:
# train.csv: 29.5MB [00:00, 84.9MB/s]

# %%
from torchdata.datapipes.iter import HttpReader
URL = "https://raw.githubusercontent.com/mhjabreel/CharCnn_Keras/master/data/ag_news_csv/train.csv"
ag_news_train = HttpReader([URL]).parse_csv().map(lambda t: (int(t[0]), " ".join(t[1:])))
agn_batches = ag_news_train.batch(2).map(lambda batch: {'labels': [sample[0] for sample in batch],\
                                      'text': [sample[1].split() for sample in batch]})
batch = next(iter(agn_batches))
print(batch)
assert batch['text'][0][0:8] == ['Wall', 'St.', 'Bears', 'Claw', 'Back', 'Into', 'the', 'Black']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-3004a1cd58d2> in <module>()
# ----> 1 from torchdata.datapipes.iter import HttpReader
#       2 URL = "https://raw.githubusercontent.com/mhjabreel/CharCnn_Keras/master/data/ag_news_csv/train.csv"
#       3 ag_news_train = HttpReader([URL]).parse_csv().map(lambda t: (int(t[0]), " ".join(t[1:])))
#       4 agn_batches = ag_news_train.batch(2).map(lambda batch: {'labels': [sample[0] for sample in batch],                                      'text': [sample[1].split() for sample in batch]})
#       5 batch = next(iter(agn_batches))
#
# /root/.local/lib/python3.7/site-packages/torchdata/__init__.py in <module>()
#       7 from torchdata import _extension  # noqa: F401
#       8
# ----> 9 from . import datapipes
#      10
#      11 try:
#
# /root/.local/lib/python3.7/site-packages/torchdata/datapipes/__init__.py in <module>()
#       5 # LICENSE file in the root directory of this source tree.
#       6
# ----> 7 from torch.utils.data import DataChunk, functional_datapipe
#       8
#       9 from . import iter, map, utils
#
# ImportError: cannot import name 'DataChunk' from 'torch.utils.data' (/usr/local/lib/python3.7/dist-packages/torch/utils/data/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
next(train_iter)
# Out:
# (3,
#  "Wall St. Bears Claw Back Into the Black (Reuters) Reuters - Short-sellers, Wall Street's dwindling\\band of ultra-cynics, are seeing green again.")

# %%
from torch.utils.data import DataLoader
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def collate_batch(batch):
    label_list, text_list, offsets = [], [], [0]
    for (_label, _text) in batch:
         label_list.append(label_pipeline(_label))
         processed_text = torch.tensor(text_pipeline(_text), dtype=torch.int64)
         text_list.append(processed_text)
         offsets.append(processed_text.size(0))
    label_list = torch.tensor(label_list, dtype=torch.int64)
    offsets = torch.tensor(offsets[:-1]).cumsum(dim=0)
    text_list = torch.cat(text_list)
    return label_list.to(device), text_list.to(device), offsets.to(device)

train_iter = AG_NEWS(split='train')
dataloader = DataLoader(train_iter, batch_size=8, shuffle=False, collate_fn=collate_batch)

# %%
# !pip install -U torchtext==0.10.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchtext==0.10.0
#   Downloading torchtext-0.10.0-cp37-cp37m-manylinux1_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 2.9 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.10.0) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.10.0) (4.64.0)
# Collecting torch==1.9.0
#   Downloading torch-1.9.0-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 2.7 kB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.10.0) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.9.0->torchtext==0.10.0) (4.2.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.10.0) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /root/.local/lib/python3.7/site-packages (from requests->torchtext==0.10.0) (1.25.11)
# Installing collected packages: torch, torchtext
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0.dev20220525+cpu
#     Uninstalling torch-1.13.0.dev20220525+cpu:
#       Successfully uninstalled torch-1.13.0.dev20220525+cpu
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.8.0
#     Uninstalling torchtext-0.8.0:
#       Successfully uninstalled torchtext-0.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchdata 0.5.0a0+24ff1b5 requires torch>1.11.0, but you have torch 1.9.0 which is incompatible.
# torchvision 0.12.0+cu113 requires torch==1.11.0, but you have torch 1.9.0 which is incompatible.
# torchaudio 0.11.0+cu113 requires torch==1.11.0, but you have torch 1.9.0 which is incompatible.
# Successfully installed torch-1.9.0 torchtext-0.10.0

# %%
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator

tokenizer = get_tokenizer('basic_english')
train_iter = AG_NEWS(split='train')

def yield_tokens(data_iter):
    for _, text in data_iter:
        yield tokenizer(text)

vocab = build_vocab_from_iterator(yield_tokens(train_iter), specials=["<unk>"])
vocab.set_default_index(vocab["<unk>"])

# %%
text_pipeline = lambda x: vocab(tokenizer(x))
label_pipeline = lambda x: int(x) - 1

# %%
from torch import nn

class TextClassificationModel(nn.Module):

    def __init__(self, vocab_size, embed_dim, num_class):
        super(TextClassificationModel, self).__init__()
        self.embedding = nn.EmbeddingBag(vocab_size, embed_dim, sparse=True)
        self.fc = nn.Linear(embed_dim, num_class)
        self.init_weights()

    def init_weights(self):
        initrange = 0.5
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.fc.weight.data.uniform_(-initrange, initrange)
        self.fc.bias.data.zero_()

    def forward(self, text, offsets):
        embedded = self.embedding(text, offsets)
        return self.fc(embedded)

# %%
train_iter = AG_NEWS(split='train')
num_class = len(set([label for (label, text) in train_iter]))
vocab_size = len(vocab)
emsize = 64
model = TextClassificationModel(vocab_size, emsize, num_class).to(device)

# %%
import time

def train(dataloader):
    model.train()
    total_acc, total_count = 0, 0
    log_interval = 500
    start_time = time.time()

    for idx, (label, text, offsets) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_label = model(text, offsets)
        loss = criterion(predicted_label, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        total_count += label.size(0)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches '
                  '| accuracy {:8.3f}'.format(epoch, idx, len(dataloader),
                                              total_acc/total_count))
            total_acc, total_count = 0, 0
            start_time = time.time()

def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, (label, text, offsets) in enumerate(dataloader):
            predicted_label = model(text, offsets)
            loss = criterion(predicted_label, label)
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)

# %%
from torch.utils.data.dataset import random_split
from torchtext.data.functional import to_map_style_dataset
# Hyperparameters
EPOCHS = 10 # epoch
LR = 5  # learning rate
BATCH_SIZE = 64 # batch size for training

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.1)
total_accu = None
train_iter, test_iter = AG_NEWS()
train_dataset = to_map_style_dataset(train_iter)
test_dataset = to_map_style_dataset(test_iter)
num_train = int(len(train_dataset) * 0.95)
split_train_, split_valid_ = \
    random_split(train_dataset, [num_train, len(train_dataset) - num_train])

train_dataloader = DataLoader(split_train_, batch_size=BATCH_SIZE,
                              shuffle=True, collate_fn=collate_batch)
valid_dataloader = DataLoader(split_valid_, batch_size=BATCH_SIZE,
                              shuffle=True, collate_fn=collate_batch)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE,
                             shuffle=True, collate_fn=collate_batch)

for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train(train_dataloader)
    accu_val = evaluate(valid_dataloader)
    if total_accu is not None and total_accu > accu_val:
      scheduler.step()
    else:
       total_accu = accu_val
    print('-' * 59)
    try:
      print('| end of epoch {:3d} | time: {:5.2f}s | '
            'valid accuracy {:8.3f} '.format(epoch,
                                            time.time() - epoch_start_time,
                                            accu_val))
    except Exception as e:
      print("| end of epoch------------------------------") 

    print('-' * 59)
# Out:
# | epoch   1 |   500/ 1782 batches | accuracy    0.689
# | epoch   1 |  1000/ 1782 batches | accuracy    0.852
# | epoch   1 |  1500/ 1782 batches | accuracy    0.875
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------
# | epoch   2 |   500/ 1782 batches | accuracy    0.898
# | epoch   2 |  1000/ 1782 batches | accuracy    0.899
# | epoch   2 |  1500/ 1782 batches | accuracy    0.903
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------
# | epoch   3 |   500/ 1782 batches | accuracy    0.915
# | epoch   3 |  1000/ 1782 batches | accuracy    0.913
# | epoch   3 |  1500/ 1782 batches | accuracy    0.915
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------
# | epoch   4 |   500/ 1782 batches | accuracy    0.922
# | epoch   4 |  1000/ 1782 batches | accuracy    0.923
# | epoch   4 |  1500/ 1782 batches | accuracy    0.922
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------
# | epoch   5 |   500/ 1782 batches | accuracy    0.931
# | epoch   5 |  1000/ 1782 batches | accuracy    0.929
# | epoch   5 |  1500/ 1782 batches | accuracy    0.930
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------
# | epoch   6 |   500/ 1782 batches | accuracy    0.936
# | epoch   6 |  1000/ 1782 batches | accuracy    0.934
# | epoch   6 |  1500/ 1782 batches | accuracy    0.932
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------
# | epoch   7 |   500/ 1782 batches | accuracy    0.942
# | epoch   7 |  1000/ 1782 batches | accuracy    0.940
# | epoch   7 |  1500/ 1782 batches | accuracy    0.937
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------
# | epoch   8 |   500/ 1782 batches | accuracy    0.942
# | epoch   8 |  1000/ 1782 batches | accuracy    0.942
# | epoch   8 |  1500/ 1782 batches | accuracy    0.941
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------
# | epoch   9 |   500/ 1782 batches | accuracy    0.947
# | epoch   9 |  1000/ 1782 batches | accuracy    0.948
# | epoch   9 |  1500/ 1782 batches | accuracy    0.943
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------
# | epoch  10 |   500/ 1782 batches | accuracy    0.951
# | epoch  10 |  1000/ 1782 batches | accuracy    0.949
# | epoch  10 |  1500/ 1782 batches | accuracy    0.948
# -----------------------------------------------------------
# | end of epoch------------------------------
# -----------------------------------------------------------

# %% [markdown]
# I don't know why but there's a problem with the accu_val variable not working with .format()

# %%
def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, (label, text, offsets) in enumerate(dataloader):
            predicted_label = model(text, offsets)
            loss = criterion(predicted_label, label)
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc/total_count

# %%
print('Checking the results of test dataset.')
accu_test = evaluate(test_dataloader)
print('test accuracy {:8.3f}'.format(accu_test))
# Out:
# Checking the results of test dataset.
# test accuracy    0.907

# %%
ag_news_label = {1: "World",
                 2: "Sports",
                 3: "Business",
                 4: "Sci/Tec"}

def predict(text, text_pipeline):
    with torch.no_grad():
        text = torch.tensor(text_pipeline(text))
        output = model(text, torch.tensor([0]))
        return output.argmax(1).item() + 1

ex_text_str = "MEMPHIS, Tenn. – Four days ago, Jon Rahm was \
    enduring the season’s worst weather conditions on Sunday at The \
    Open on his way to a closing 75 at Royal Portrush, which \
    considering the wind and the rain was a respectable showing. \
    Thursday’s first round at the WGC-FedEx St. Jude Invitational \
    was another story. With temperatures in the mid-80s and hardly any \
    wind, the Spaniard was 13 strokes better in a flawless round. \
    Thanks to his best putting performance on the PGA Tour, Rahm \
    finished with an 8-under 62 for a three-stroke lead, which \
    was even more impressive considering he’d never played the \
    front nine at TPC Southwind."

model = model.to("cpu")

print("This is a %s news" %ag_news_label[predict(ex_text_str, text_pipeline)])
# Out:
# This is a Sports news
